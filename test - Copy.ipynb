# %%
import sys
import os

# Add backend folder to path so utils work
sys.path.append(r"C:\Users\disha\VoiceAgent\backend")

from utils.stt_vosk import speech_to_text
from utils.emotion_predict import predict_emotion
from utils.tts import speak

from fastapi import FastAPI, UploadFile, File
from fastapi.responses import JSONResponse
import uvicorn

print("IMPORTS OK ✓")
# Out:
# IMPORTS OK ✓

# %%
from fastapi import FastAPI, UploadFile, File
import uvicorn

app = FastAPI()

# %%
import sys
sys.path.append(r"C:\Users\disha\VoiceAgent\backend")

from utils.stt_vosk import speech_to_text
from utils.emotion_predict import predict_emotion
from utils.tts import speak

# %%
@app.post("/transcribe")
async def transcribe_audio(file: UploadFile = File(...)):
    temp_path = "temp_audio.wav"
    with open(temp_path, "wb") as f:
        f.write(await file.read())

    text = speech_to_text(temp_path)
    emotion = predict_emotion(temp_path)
    reply_audio = speak(text)

    return {
        "text": text,
        "emotion": emotion,
        "reply_audio": reply_audio
    }

# %%
# !pip install python-multipart

# %%
pip install vosk soundfile
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.0 MB 621.2 kB/s eta 0:00:22
#    -- ------------------------------------- 0.8/14.0 MB 657.8 kB/s eta 0:00:21
#    -- ------------------------------------- 0.8/14.0 MB 657.8 kB/s eta 0:00:21
#    -- ------------------------------------- 1.0/14.0 MB 671.0 kB/s eta 0:00:20
#    -- ------------------------------------- 1.0/14.0 MB 671.0 kB/s eta 0:00:20
#    --- ------------------------------------ 1.3/14.0 MB 627.1 kB/s eta 0:00:21
# ...

# %%
pip install librosa tensorflow numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# ...
#
# ...
